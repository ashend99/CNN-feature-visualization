# %%
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import numpy as np
from models import SimpleCNN, trainset, testset, trainloader, testloader
# Out:
# 100%|██████████| 170M/170M [00:17<00:00, 9.69MB/s]

# %%
model = SimpleCNN()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
epochs = 10

for epoch in range(epochs):
    running_loss = 0.0
    
    for images, labels in trainloader:        
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
    
    print(f"Epoch {epoch+1}, Loss: {running_loss:.3f}")
# Out:
# Epoch 1, Loss: 1126.104
# Epoch 2, Loss: 794.116
# Epoch 3, Loss: 646.633
# Epoch 4, Loss: 548.921
# Epoch 5, Loss: 475.348
# Epoch 6, Loss: 408.938
# Epoch 7, Loss: 352.900
# Epoch 8, Loss: 301.561
# Epoch 9, Loss: 254.309
# Epoch 10, Loss: 216.929

# %%
correct = 0
total = 0

with torch.no_grad():
    for images, labels in testloader:
        outputs = model(images)
        _, predicted = torch.max(outputs, 1)
        
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f"Accuracy: {100 * correct / total:.2f}%")
# Out:
# Accuracy: 73.47%

# %%
torch.save(model.state_dict(), "../models/cnn_cifar10.pth")
